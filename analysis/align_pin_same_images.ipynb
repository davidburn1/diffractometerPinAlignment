# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

# %%
""" data for multiple analysis of same images """
xc = [18.4560407, 18.4967424, 18.5124407, 18.8129329, 18.3600057, 18.3816670, 18.5889185, 17.8094580, 19.2290324, 18.8236925, 18.8879747, 18.5185034, 18.5146375, 18.1160468, 18.9385174, 19.7539467]
xc_err = [.163134, 0.077108, 0.101574, 0.122890, 0.158586, 0.198874, 0.232794, 0.125344, 0.210798, 0.202282, 0.035650, 0.092106, 0.075518, 0.141571, 0.139434, 0.181422]

yc = [-0.14822983, -0.09645062, -0.10670527, -0.10531142, -0.11345309, -0.08359731, -0.11804819, -0.10871217, -0.16403874, 0.09199722, -0.13489096, -0.12073036, -0.11455457, -0.11857461, -0.11362521, -0.08753448] 
yc_err = [0.021645, 0.027400, 0.027599, 0.024818, 0.038906, 0.024625, 0.044279, 0.016480, 0.039958, 0.024378, 0.011319, 0.020348, 0.013452, 0.030162, 0.028393, 0.059843]

zc = [-0.15285881, -0.13174936, -0.10849944, -0.14102938, -0.10651761, -0.09694700, -0.13676673, -0.09695398, -0.06866088, -0.12939508, -0.11183869, 0.03390705, -0.18318204, -0.04669537, -0.16460190, 0.12902728]
zc_err=[ 0.056805, 0.072968, 0.036101, 0.054163, 0.057040, 0.076237, 0.098849, 0.032953, 0.079615, 0.088143, 0.026656, 0.123696, 0.031829, 0.059835, 0.067615, 0.133050]

xc = xc[:15]
yc = yc[:15]
zc = zc[:15]

xc_err = xc_err[:15]
yc_err = yc_err[:15]
zc_err = zc_err[:15]

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 6), facecolor='w', sharex=True, sharey=False)

fig.add_subplot(111, frameon=False)# big frame
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')


ax[0].errorbar(range(15), xc-np.mean(xc), xc_err)
ax[1].errorbar(range(15), yc-np.mean(yc), yc_err)
ax[2].errorbar(range(15), zc-np.mean(zc), zc_err)

ax[0].text(0, 0.7, 'x', style='italic',verticalalignment='center', horizontalalignment='center')
ax[1].text(0, 0.13, 'y', style='italic',verticalalignment='center', horizontalalignment='center')
ax[2].text(0, 0.13, 'z', style='italic',verticalalignment='center', horizontalalignment='center')


ax[2].set_ylim([-0.2, 0.2])
ax[1].set_ylim([-0.2, 0.2])
ax[0].set_ylim([-1, 1])

ax[1].set_ylabel('Position difference (mm)')
plt.xlabel('Repeats')

plt.savefig('graphics/same_image_variation.png')
plt.show()

# %%
print "xc std microns ", np.std(xc)*1000
print "yc std microns ", np.std(yc)*1000
print "zc std microns ", np.std(zc)*1000
# Out:
# xc std microns  335.231879499
# yc std microns  55.6273068369
# zc std microns  51.3042055798
